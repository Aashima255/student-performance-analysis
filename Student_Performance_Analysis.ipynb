# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create dataset manually
data = {
    "Study_Hours": [1,2,3,4,5,6,7,8,2,3,5,6,7,8,9],
    "Attendance": [60,65,70,75,80,85,90,95,68,72,78,88,92,96,98],
    "Marks": [35,40,50,55,65,70,75,85,45,52,67,72,80,88,92]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    Study_Hours  Attendance  Marks
# 0            1          60     35
# 1            2          65     40
# 2            3          70     50
# 3            4          75     55
# 4            5          80     65

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Study_Hours  15 non-null     int64
#  1   Attendance   15 non-null     int64
#  2   Marks        15 non-null     int64
# dtypes: int64(3)
# memory usage: 492.0 bytes
#        Study_Hours  Attendance      Marks
# count    15.000000   15.000000  15.000000
# mean      5.066667   80.800000  64.733333
# std       2.491892   12.219422  17.886414
# min       1.000000   60.000000  35.000000
# 25%       3.000000   71.000000  51.000000
# 50%       5.000000   80.000000  67.000000
# 75%       7.000000   91.000000  77.500000
# max       9.000000   98.000000  92.000000

# %%
sns.scatterplot(x="Study_Hours", y="Marks", data=df)
plt.title("Study Hours vs Marks")
plt.show()

# %%
sns.scatterplot(x="Attendance", y="Marks", data=df)
plt.title("Attendance vs Marks")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[["Study_Hours", "Attendance"]]
y = df["Marks"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Predictions:", predictions)
# Out:
# Predictions: [71.44171919 43.08451667 64.35241856]

# %%
from sklearn.metrics import mean_absolute_error

print("Error:", mean_absolute_error(y_test, predictions))
# Out:
# Error: 1.724605766066773
